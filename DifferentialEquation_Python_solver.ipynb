# %%
from sympy import Symbol
from sympy import *
import sympy
from math import sqrt
from fractions import Fraction
print("Q1.(D^2 − 7D + 12)y = e^(2x)(x^3 − 5x^2)\n")
# for roots
a = 1
b = -7
c = 12
r = b**2 - 4*a*c
if r > 0:
 num_roots = 2
 x1 = (((-b) + sqrt(r))/(2*a))
 x2 = (((-b) - sqrt(r))/(2*a))

print("There are 2 roots: %.2f and %.2f" % (x1, x2))
# print for yc
x = Symbol('x')
C1 = Symbol('C1')
C2 = Symbol('C2')
yc = C1*exp(x1*x) + C2*exp(x2*x)
print("yc =" ,yc)
# print for yp
x = Symbol('x')
A = Symbol('A')
B = Symbol('B')
C = Symbol('C')
E = Symbol('E')
f = sympy.exp(2*x)*(A*x**3 + B*x**2 + C*x + E)
print("yp = ",f)
f_derivative = Derivative(f, x)
f_derivative = f_derivative.doit() # do the derivative and assign it to variable
print("\n1st derivate : ", simplify(f_derivative))
f_derivative2 = Derivative(f_derivative, x)
f_derivative2 = f_derivative2.doit()
print("2nd derivate : ", simplify(f_derivative2))
equation = f_derivative2 - (7*f_derivative) + 12*f
print(equation)

lhs = simplify(f_derivative2 - 7*f_derivative + 12*f)
print(lhs)
A=1/2
B=1/4
C=1/4
E=25/8
A = Fraction(1, 2)
B = Fraction(1, 2)
C = Fraction(1, 4)
E = Fraction(25, 8)
yp = sympy.exp(2*x)*(A*x**3 + B*x**2 + C*x + E)
print("\ny = ",yc+yp)
# Out:
# Q1.(D^2 − 7D + 12)y = e^(2x)(x^3 − 5x^2)
#
# There are 2 roots: 4.00 and 3.00
# yc = C1*exp(4.0*x) + C2*exp(3.0*x)
# yp =  (A*x**3 + B*x**2 + C*x + E)*exp(2*x)
#
# 1st derivate :  (2*A*x**3 + 3*A*x**2 + 2*B*x**2 + 2*B*x + 2*C*x + C + 2*E)*exp(2*x)
# 2nd derivate :  2*(2*A*x**3 + 6*A*x**2 + 3*A*x + 2*B*x**2 + 4*B*x + B + 2*C*x + 2*C + 2*E)*exp(2*x)
# (6*A*x + 2*B)*exp(2*x) - 3*(3*A*x**2 + 2*B*x + C)*exp(2*x) + 2*(A*x**3 + B*x**2 + C*x + E)*exp(2*x)

# %%
from sympy import *
import sympy
from math import sqrt
from fractions import Fraction
# for roots
print("Q2.y′′ + y′ − 2y = x^2 + 2sinx − e^(3x)\n")
a = 1
b = 1
c = -2
r = b**2 - 4*a*c
if r > 0:
 num_roots = 2
 x1 = (((-b) + sqrt(r))/(2*a))
 x2 = (((-b) - sqrt(r))/(2*a))

print("There are 2 roots: %i and %i" % (x1, x2))
# print for yc
x = sympy.Symbol('x')
C1 = sympy.Symbol('C1')
C2 = sympy.Symbol('C2')
yc = C1*exp(x1*x) + C2*exp(x2*x)
print("yc = ", yc)
#print yp
A = Symbol('A')
B = Symbol('B')
C = Symbol('C')
D = Symbol('D')
E = Symbol('E')
sin_x = sympy.sin(x)
f = A*x**2 + B*x + C*sin_x + D*sympy.cos(x) + E*sympy.exp(3*x)
print(f)
f_derivative = Derivative(f, x)
f_derivative = f_derivative.doit() # do the derivative and assign it to variable
print("1st derivate : ", simplify(f_derivative))
f_derivative2 = Derivative(f_derivative, x)
f_derivative2 = f_derivative2.doit()
print("2nd derivate : ", simplify(f_derivative2))
equation = f_derivative2 + (f_derivative) - 2*f
#print(equation)
lhs = simplify(f_derivative2 + (f_derivative) - 2*f)
print(lhs)
#solving for coeff
print("\nSolving Coeffecients : ")
print(-2*A ,"=", A)
print(-3*C - D,"=", 2)
print(C - 3*D ,"=", 0)
print(2*A - A*B ,"=", 0)
print(-10*E ,"=", 1)
A = Fraction(-1, 2)
B = Fraction(-1, 2)
C = Fraction(-2, 3)
D = Fraction(-2, 9)
E = Fraction(-1, 10)
yh = yc+ A*x**2 + B*x + C*sin_x + D*sympy.cos(x) + E*sympy.exp(3*x)
print("General solution yc + yp = ",yh)
# Out:
# Q2.y′′ + y′ − 2y = x^2 + 2sinx − e^(3x)
#
# There are 2 roots: 1 and -2
# yc =  C1*exp(1.0*x) + C2*exp(-2.0*x)
# A*x**2 + B*x + C*sin(x) + D*cos(x) + E*exp(3*x)
# 1st derivate :  2*A*x + B + C*cos(x) - D*sin(x) + 3*E*exp(3*x)
# 2nd derivate :  2*A - C*sin(x) - D*cos(x) + 9*E*exp(3*x)
# -2*A*x**2 + 2*A*x + 2*A - 2*B*x + B - 3*C*sin(x) + C*cos(x) - D*sin(x) - 3*D*cos(x) + 10*E*exp(3*x)
#
# Solving Coeffecients :
# -2*A = A
# -3*C - D = 2
# C - 3*D = 0
# -A*B + 2*A = 0
# -10*E = 1
# General solution yc + yp =  C1*exp(1.0*x) + C2*exp(-2.0*x) - x**2/2 - x/2 - exp(3*x)/10 - 2*sin(x)/3 - 2*cos(x)/9

# %%
from sympy import *
import sympy
from fractions import Fraction
import numpy as np
print("Q3. y′′ − 2y′ + 2y = e^(2x)(cosx − 3sinx)\n")
# for roots
m = symbols('m')
equation = m**2 - 2*m + 2
roots = solve(equation, m)
print("The roots of the equation are:", roots)
# print for yc
x = sympy.Symbol('x')
C1 = sympy.Symbol('C1')
C2 = sympy.Symbol('C2')
yc = C1*exp(x)*cos(x) + C2*exp(x)*sin(x)
print("yc = ", yc)
A = Symbol('A')
B = Symbol('B')
f =(A*cos(x) + B*sin(x))*exp(2*x)
print("yp =", f)
d1 = diff(f, x)
print("1st derivate : ",d1)
d2 = diff(d1, x)
print("2nd derivate : ",simplify(d2))
lhs = (d2 - 2*(d1) + 2*f)
print("Placing derivatives in function : ",lhs)
print("\nSolving coeffecients")
print(A + 2*B, " = " ,1)
print(-2*A + B, " = " ,-3)
a = ([[1, 2], [-2, 1]])
b = ([1, -3])
x1 = np.linalg.solve(a,b)
A = Fraction(x1[0]).limit_denominator()
B = Fraction(x1[1]).limit_denominator()
print("A =",A,"B =", B)
yp =(A*cos(x) + B*sin(x))*exp(2*x)
yh = yc + yp
print("General solution yc + yp = ",yh)
# Out:
# Q3. y′′ − 2y′ + 2y = e^(2x)(cosx − 3sinx)
#
# The roots of the equation are: [1 - I, 1 + I]
# yc =  C1*exp(x)*cos(x) + C2*exp(x)*sin(x)
# yp = (A*cos(x) + B*sin(x))*exp(2*x)
# 1st derivate :  (-A*sin(x) + B*cos(x))*exp(2*x) + 2*(A*cos(x) + B*sin(x))*exp(2*x)
# 2nd derivate :  (-4*A*sin(x) + 3*A*cos(x) + 3*B*sin(x) + 4*B*cos(x))*exp(2*x)
# Placing derivatives in function :  2*(-A*sin(x) + B*cos(x))*exp(2*x) + (-A*cos(x) - B*sin(x))*exp(2*x) + 2*(A*cos(x) + B*sin(x))*exp(2*x)
#
# Solving coeffecients
# A + 2*B  =  1
# -2*A + B  =  -3
# A = 7/5 B = -1/5
# General solution yc + yp =  C1*exp(x)*cos(x) + C2*exp(x)*sin(x) + (-sin(x)/5 + 7*cos(x)/5)*exp(2*x)

# %%
from sympy import *
import sympy
import sympy as sp
print("Problem-2 Q1.(D^2 + 1)y = cscx\n")
y = Symbol('y')
D = Symbol('D')
m = symbols('m')
equation = m**2 +1
print("Replacing D with m =" ,equation,"=",0)
roots = solve(equation, m)
print("The roots of the equation are:", roots)
# print for yc
x = sympy.Symbol('x')
C1 = sympy.Symbol('C1')
C2 = sympy.Symbol('C2')
y1=cos(x)
y2=sin(x)
yc = C1*cos(x) + C2*sin(x)
print("yc = ", yc)
x = sympy.Symbol('x')
var = x
Wronskian_Sol = sp.matrices.dense.wronskian([ sp.cos(x), sp.sin(x)], var, method="bareiss")
#print(Wronskian_Sol)
print("W =",Wronskian_Sol.simplify())
W1 = sp.Matrix([[0, sp.csc(x)], [sp.sin(x), sp.cos(x)]])
det = W1.det()
print("W1 =",det)
W2 = sp.Matrix([[sp.cos(x), -sp.sin(x)], [0, sp.csc(x)]])
det2 = W2.det()
print("W2 =",det2)
# integration
w=Wronskian_Sol.simplify()
w1=det
w2=det2
x = sp.Symbol('x')
f = w1/w
u1 = sp.integrate(f, x)
print("The integral of u1 is:", u1)
f2 = w2/w
u2 = sp.integrate(f2, x)
print("The integral of u2 is:", u2)
y= yc + y1*u1 + y2*u2
print("\n")
print("y =",y)
# Out:
# Problem-2 Q1.(D^2 + 1)y = cscx
#
# Replacing D with m = m**2 + 1 = 0
# The roots of the equation are: [-I, I]
# yc =  C1*cos(x) + C2*sin(x)
# W = 1
# W1 = -sin(x)*csc(x)
# W2 = cos(x)*csc(x)
# The integral of u1 is: -x
# The integral of u2 is: log(sin(x))
#
#
# y = C1*cos(x) + C2*sin(x) - x*cos(x) + log(sin(x))*sin(x)

# %%
from sympy import *
import sympy
import sympy as sp
print("Problem-2 Q2. y′′′ + y′ = tanx\n")
y = Symbol('y')
D = Symbol('D')
print((D**3 + D)*y, "=", tan(x))
m = symbols('m')
equation = m**3 + m
print("Replacing D with m =" ,equation,"=",0)
roots = solve(equation, m)
print("The roots of the equation are:", roots)
# print for yc
x = sympy.Symbol('x')
C1 = sympy.Symbol('C1')
C2 = sympy.Symbol('C2')
C3 = sympy.Symbol('C3')
yc = C1 + C2*cos(x) + C3*sin(x)
print("yc = ", yc)
y1 = 1
y2 = cos(x)
y3 = sin(x)
x = sympy.Symbol('x')
var = x
Wronskian_Sol = sp.matrices.dense.wronskian([ y1,y2,y3 ], var, method="bareiss")
print("W =",Wronskian_Sol.simplify())
dy = sp.diff(y1, x)
dyy = sp.diff(dy, x)
dy1 = sp.diff(y2, x)
dy2 = sp.diff(dy1, x)
dy21 = sp.diff(y3, x)
dy22 = sp.diff(dy21, x)

W1 = sp.Matrix([[0, 0,sp.tan(x)], [y2,dy1,dy2],[ y3,dy21,dy22]])
det = W1.det()
print("W1 =",simplify(det))
W2 = sp.Matrix([[y1,dy,dyy],[0, 0,sp.tan(x)],[ y3,dy21,dy22]])
det2 = W2.det()
print("W2 =",simplify(det2))
W3 = sp.Matrix([[y1,dy,dyy],[ y2,dy1,dy2],[0, 0,sp.tan(x)]])
det3 = W3.det()
print("W3 =",simplify(det3))
# integration
w=Wronskian_Sol.simplify()
w1=det
w2=det2
w3=det3
x = sp.Symbol('x')
f = w1/w
u1 = sp.integrate(f, x)
print("The integral of u1 is:", simplify(u1))
f2 = w2/w
u2 = sp.integrate(f2, x)
print("The integral of u2 is:", u2)
f3 = w3/w
u3 = sp.integrate(f3, x)
print("The integral of u3 is:", simplify(u3))
y= yc + y1*u1 + y2*u2 + y3*u3
print("y = ",y,"\n")
print("simplified version : ",simplify(y))
# Out:
# Problem-2 Q2. y′′′ + y′ = tanx
#
# y*(D**3 + D) = tan(x)
# Replacing D with m = m**3 + m = 0
# The roots of the equation are: [0, -I, I]
# yc =  C1 + C2*cos(x) + C3*sin(x)
# W = 1
# W1 = tan(x)
# W2 = -sin(x)
# W3 = -sin(x)*tan(x)
# The integral of u1 is: 1/2 - log(cos(x))
# The integral of u2 is: cos(x)
# The integral of u3 is: log(sin(x) - 1)/2 - log(sin(x) + 1)/2 + sin(x)
# y =  C1 + C2*cos(x) + C3*sin(x) + (log(sin(x) - 1)/2 - log(sin(x) + 1)/2 + sin(x))*sin(x) - log(cos(x)) + sin(x)**2/2 + 3*cos(x)**2/2
#
# simplified version :  C1 + C2*cos(x) + C3*sin(x) + log(sin(x) - 1)*sin(x)/2 - log(sin(x) + 1)*sin(x)/2 - log(cos(x)) + 3/2

# %%
from sympy import *
import sympy
import sympy as sp
print("Problem-2 Q3. y′′′ + 4y′ = sec2x\n")
x = sympy.Symbol('x')
y = Symbol('y')
D = Symbol('D')
print((D**3 + 4*D)*y, "=", sec(2*x))
m = symbols('m')
equation = m**3 + 4*m
print("Replacing D with m =" ,equation,"=",0)
roots = solve(equation, m)
print("The roots of the equation are:", roots)
# print for yc
C1 = sympy.Symbol('C1')
C2 = sympy.Symbol('C2')
C3 = sympy.Symbol('C3')
yc = C1 + C2*cos(x) + C3*sin(x)
print("yc = ", yc)
y1 = 1
y2 = cos(x)
y3 = sin(x)
x = sympy.Symbol('x')
var = x
Wronskian_Sol = sp.matrices.dense.wronskian([ y1,y2,y3 ], var, method="bareiss")
print("W =",Wronskian_Sol.simplify())
dy = sp.diff(y1, x)
dyy = sp.diff(dy, x)
dy1 = sp.diff(y2, x)
dy2 = sp.diff(dy1, x)
dy21 = sp.diff(y3, x)
dy22 = sp.diff(dy21, x)
W1 = sp.Matrix([[0, 0,sp.sec(2*x)], [y2,dy1,dy2],[ y3,dy21,dy22]])
det = W1.det()
print("W1 =",simplify(det))
W2 = sp.Matrix([[y1,dy,dyy],[0, 0,sp.sec(2*x)],[ y3,dy21,dy22]])
det2 = W2.det()
print("W2 =",simplify(det2))

W3 = sp.Matrix([[y1,dy,dyy],[ y2,dy1,dy2],[0, 0,sp.sec(2*x)]])
det3 = W3.det()
print("W3 =",simplify(det3))
# integration
w=Wronskian_Sol.simplify()
w1=det
w2=det2
w3=det3
x = sp.Symbol('x')
f = w1/w
u1 = sp.integrate(f, x)
print("The integral of u1 is:", simplify(u1))
f2 = w2/w
u2 = sp.integrate(f2, x)
print("The integral of u2 is:", u2)
f3 = w3/w
u3 = sp.integrate(f3, x)
print("The integral of u3 is:", simplify(u3))
y= yc + y1*u1 + y2*u2 + y3*u3
print("y = ",y,"\n")
print("simplified version : ",simplify(y))
# Out:
# Problem-2 Q3. y′′′ + 4y′ = sec2x
#
# y*(D**3 + 4*D) = sec(2*x)
# Replacing D with m = m**3 + 4*m = 0
# The roots of the equation are: [0, -2*I, 2*I]
# yc =  C1 + C2*cos(x) + C3*sin(x)
# W = 1
# W1 = sec(2*x)
# W2 = -cos(x)*sec(2*x)
# W3 = -sin(x)*sec(2*x)
# The integral of u1 is: Integral(sec(2*x), x)
# The integral of u2 is: -Integral(cos(x)*sec(2*x), x)
# The integral of u3 is: -Integral(sin(x)*sec(2*x), x)
# y =  C1 + C2*cos(x) + C3*sin(x) - sin(x)*Integral(sin(x)*sec(2*x), x) - cos(x)*Integral(cos(x)*sec(2*x), x) + Integral((sin(x)**2 + cos(x)**2)*sec(2*x), x)
#
# simplified version :  C1 + C2*cos(x) + C3*sin(x) - log(sin(2*x) - 1)/4 + log(sin(2*x) + 1)/4 - sin(x)*Integral(sin(x)*sec(2*x), x) - cos(x)*Integral(cos(x)*sec(2*x), x)

# %%
import sympy as sp
print("Problem-2 Q4. y′′′ − 2y′′ − y′ + 2y = e^(4x)\n")
x = sp.Symbol('x')
C1, C2,C3 = sp.symbols('C1 C2 C3')
y = sp.Function('y')(x)
de = sp.diff(y, x, x,x) -2*sp.diff(y,x,x)-sp.diff(y,x) +2*y - (sp.exp(4*x))
y_h = sp.dsolve(de.subs(sp.exp(4*x), 0), y)
y_h1 = y_h.rhs.subs(C1, 1).subs(C2, 0).subs(C3, 0)
y_h2 = y_h.rhs.subs(C1, 0).subs(C2, 1).subs(C3, 0)
y_h3 = y_h.rhs.subs(C1, 0).subs(C2, 0).subs(C3, 1)

W=sp.Matrix([[y_h1,y_h2,y_h3],
 [sp.diff(y_h1,x),sp.diff(y_h2,x),sp.diff(y_h3,x)],
 [sp.diff(y_h1,x,x),sp.diff(y_h2,x,x),sp.diff(y_h3,x,x)]])
W1=sp.Matrix([[0,y_h2,y_h3],[0,sp.diff(y_h2,x),sp.diff(y_h3,x)],[sp.exp(4*x),sp.diff(y_h2,x,x),
sp.diff(y_h3,x,x)]])
u1_derivative=sp.det(W1)/sp.det(W)
W2=sp.Matrix([[y_h1,0,y_h3],[sp.diff(y_h1,x),0,sp.diff(y_h3,x)],[sp.diff(y_h1,x,x),sp.exp(4*x),
sp.diff(y_h3,x,x)]])
u2_derivative=sp.det(W2)/sp.det(W)
W3=sp.Matrix([[y_h1,y_h2,0],[sp.diff(y_h1,x),sp.diff(y_h2,x),0],[sp.diff(y_h1,x,x),sp.diff(y_h2
,x,x),sp.exp(4*x)]])
u3_derivative=sp.det(W3)/sp.det(W)
u1=sp.integrate(u1_derivative,x)
u2=sp.integrate(u2_derivative,x)
u3=sp.integrate(u3_derivative,x)

print("The integral of u1 is:", u1)
print("The integral of u2 is:", u2)
print("The integral of u3 is:", u3)

yp= y_h1*u1 + y_h2*u2 +y_h3*u3
yc= C1*y_h1+ C2*y_h2 +C3*y_h3
y=yc+yp
print("\nyc + yp = ",sp.simplify(y))
# Out:
# Problem-2 Q4. y′′′ − 2y′′ − y′ + 2y = e^(4x)
#
# The integral of u1 is: exp(5*x)/30
# The integral of u2 is: -exp(3*x)/6
# The integral of u3 is: exp(2*x)/6
#
# yc + yp =  C1*exp(-x) + C2*exp(x) + C3*exp(2*x) + exp(4*x)/30

# %%
import sympy as sp
print("Problem-2 Q5.y''' - 3y'' + 2y' = e^(2x)/(1+e^x)\n")
x = sp.Symbol('x')
C1, C2,C3 = sp.symbols('C1 C2 C3')
y = sp.Function('y')(x)
de = sp.diff(y, x, x,x) -3*sp.diff(y,x,x)+2*sp.diff(y,x) - (sp.exp(2*x)/(1+sp.exp(x)))
y_h = sp.dsolve(de.subs(sp.exp(2*x)/(1+sp.exp(x)), 0), y)
y_h1 = y_h.rhs.subs(C1, 1).subs(C2, 0).subs(C3, 0)
y_h2 = y_h.rhs.subs(C1, 0).subs(C2, 1).subs(C3, 0)
y_h3 = y_h.rhs.subs(C1, 0).subs(C2, 0).subs(C3, 1)

W=sp.Matrix([[y_h1,y_h2,y_h3],
 [sp.diff(y_h1,x),sp.diff(y_h2,x),sp.diff(y_h3,x)],
 [sp.diff(y_h1,x,x),sp.diff(y_h2,x,x),sp.diff(y_h3,x,x)]])
W1=sp.Matrix([[0,y_h2,y_h3],[0,sp.diff(y_h2,x),sp.diff(y_h3,x)],[sp.exp(2*x)/(1+sp.exp(x)),sp.
diff(y_h2,x,x),sp.diff(y_h3,x,x)]])
u1_derivative=sp.det(W1)/sp.det(W)
W2=sp.Matrix([[y_h1,0,y_h3],[sp.diff(y_h1,x),0,sp.diff(y_h3,x)],[sp.diff(y_h1,x,x),sp.exp(2*x)
/(1+sp.exp(x)),sp.diff(y_h3,x,x)]])
u2_derivative=sp.det(W2)/sp.det(W)
W3=sp.Matrix([[y_h1,y_h2,0],[sp.diff(y_h1,x),sp.diff(y_h2,x),0],[sp.diff(y_h1,x,x),sp.diff(y_h2
,x,x),sp.exp(2*x)/(1+sp.exp(x))]])
u3_derivative=sp.det(W3)/sp.det(W)

u1=sp.integrate(u1_derivative,x)
u2=sp.integrate(u2_derivative,x)
u3=sp.integrate(u3_derivative,x)

print("The integral of u1 is:", u1)
print("The integral of u2 is:", u2)
print("The integral of u3 is:", u3)

yp= y_h1*u1 + y_h2*u2 +y_h3*u3
yc= C1*y_h1+ C2*y_h2 +C3*y_h3
y=yc+yp
print("\nyc + yp = ",sp.simplify(y))
# Out:
# Problem-2 Q5.y''' - 3y'' + 2y' = e^(2x)/(1+e^x)
#
# The integral of u1 is: exp(x)/2 - log(exp(x) + 1)/2
# The integral of u2 is: -log(exp(x) + 1)
# The integral of u3 is: x/2 - log(exp(x) + 1)/2
#
# yc + yp =  C1 + C2*exp(x) + C3*exp(2*x) + (x - log(exp(x) + 1))*exp(2*x)/2 - exp(x)*log(exp(x) + 1) + exp(x)/2 - log(exp(x) + 1)/2

# %%
import sympy as sp
print("Problem-3 Q1.x 2y'' − 2xy' + 2y = x 4e^x\n")
x = sp.Symbol('x')
m=sp.Symbol('m')
C1, C2= sp.symbols('C1 C2')
y = sp.Function('y')(x)
de = x**2*sp.diff(y, x, x) -2*x*sp.diff(y,x)+2*y- (sp.exp(x)* x**4)
forYc= de.subs(x**2*sp.diff(y, x, x),m*(m-1)*y).subs(x*sp.diff(y,x),m*y)
y_h = sp.dsolve(de.subs(sp.exp(x)* x**4, 0), y)
y_h1 = y_h.rhs.subs(C1, 1).subs(C2, 0)
y_h2 = y_h.rhs.subs(C1, 0).subs(C2, 1)

yc=C1*y_h1+C2*y_h2

W=sp.det(sp.Matrix([[y_h1,y_h2],
 [sp.diff(y_h1),sp.diff(y_h2)]]))
u1_derivative= (-y_h2 * (sp.exp(x)* x**4)/x**2)/W
u1=sp.integrate(u1_derivative)
u2_derivative= (y_h1 * (sp.exp(x)* x**4)/x**2)/W
u2=sp.integrate(u2_derivative)

print("The integral of u1 is:", u1)
print("The integral of u2 is:", u2)

yp=y_h1*u1 + y_h2*u2
y=yc+sp.expand(yp)
print("\nyc + yp = ",y)
# Out:
# Problem-3 Q1.x 2y'' − 2xy' + 2y = x 4e^x
#
# The integral of u1 is: (-x**2 + 2*x - 2)*exp(x)
# The integral of u2 is: (x - 1)*exp(x)
#
# yc + yp =  C1*x + C2*x**2 + x**2*exp(x) - 2*x*exp(x)

# %%
import sympy as sp
print("Problem-3 Q2.x^2y'' + xy' - y = 1/(1+x)\n")
x = sp.Symbol('x')
m = sp.Symbol('m')
C1, C2 = sp.symbols('C1 C2')
y = sp.Function('y')(x)
de = x**2*sp.diff(y, x, x) + x*sp.diff(y,x) - y - (1/(1+x))
forYc = de.subs(x**2*sp.diff(y, x, x), m*(m-1)*y).subs(x*sp.diff(y,x), m*y)
y_h = sp.dsolve(de.subs(1/(1+x), 0), y)
y_h1 = y_h.rhs.subs(C1, 1).subs(C2, 0)
y_h2 = y_h.rhs.subs(C1, 0).subs(C2, 1)

yc = C1*y_h1 + C2*y_h2

yc = yc.simplify()
#forYp
W=sp.det(sp.Matrix([[y_h1,y_h2],
 [sp.diff(y_h1),sp.diff(y_h2)]]))
u1_derivative= (-y_h2 * ( 1/(1+x) ))/W
u1=sp.integrate(u1_derivative)
u2_derivative= (y_h1 * ( 1/(1+x) ))/W
u2=sp.integrate(u2_derivative)

print("The integral of u1 is:", u1)
print("The integral of u2 is:", u2)

yp=y_h1*u1 + y_h2*u2
y=yc+sp.expand(yp)
print("\nyc + yp = ",y)
# Out:
# Problem-3 Q2.x^2y'' + xy' - y = 1/(1+x)
#
# The integral of u1 is: -x**2/4 + x/2 - log(x + 1)/2
# The integral of u2 is: log(2*x + 2)/2
#
# yc + yp =  C1/x + C2*x + x*log(2*x + 2)/2 - x/4 + 1/2 - log(x + 1)/(2*x)
